# %%
datalist=[]
with open('./competive_data/SampleData_deid.txt', 'r', encoding="utf-8") as f:
    x = ''
    for line in f:
        if line != '--------------------\n':
            x = x + line + '\n'
        else:
            datalist.append(x)
            x = ''

# %%
len(datalist)
# Out:
# 26

# %%
datadir = {}
for i, j in enumerate(datalist):
    c = []
    c1 = j.split('\n')
    for k in c1:
        if k:
            c.append(k)
    datadir[i] = c

# %%
datadir[1]
# Out:
# ['醫師：啊最近的狀況還好嗎？民眾：還好啦。醫師：還好啦齁，一樣肚子還是不舒服。民眾：肚子會悶，啊之後有在吃那個......。醫師：有比較好嗎？民眾：若元胃腸錠。醫師：若元胃腸錠喔。民眾：沒錯，之後就吃那個。醫師：益生菌這樣喔。家屬：對啦他都有在吃這個，也有買優酪乳在喝。醫師：啊有差別嗎？民眾：有比較......有比較好一點，肚子比較不會脹脹的。醫師：比較不會脹脹的齁。民眾：對的，啊一天吃一次而已，吃不同藥之間有隔一段時間啦。醫師：喔吃不同藥有隔一段時間這樣喔。民眾：啊中午的時候我沒有藥可以吃，我就會吃一個中午的。醫師：啊那我們這次超音波拍起來齁，這個本身腎臟看起來已經都萎縮了，因為你已經在開始洗腎了，所以那個整個腎臟都萎縮啊。民眾：都壞了。醫師：都壞了。民眾：那個小姐也跟我說你在洗腎了齁？啊我就說對啊。醫師：腎臟都萎縮了、都乾掉了，啊這個是肝臟，啊但是稍微有一點腹水。民眾：嗯。醫師：稍微有一點腹水。家屬：肚子裡面有水。醫師：肚子裡面有水。民眾：嗯，肚子裡面有水。醫師：不過只有一點點而已，不多。嗯......腹膜水，伯伯你本身是心臟不太好嗎？民眾：對。家屬：剛剛那個心臟瓣膜有那個......醫師：你有去開刀嗎？沒去開刀嗎？民眾：有啊，我之前在奇美醫院開刀。醫師：喔。家屬：心臟就說要再觀察。醫師：只有支架喔。民眾：沒有，沒有支架。家屬：主要是那個瓣膜好像硬化。醫師：喔，那腳會不會水腫，沒有吧？民眾：稍微有一點。醫師：稍微有一點。民眾：你要是捏大力一點。醫師：我調之前的超音波片，比較一下。民眾：我是在說，那個，有沒有可能是之前開刀......。醫師：開刀所引起的？民眾：引起的。家屬：他那個做腹腔鏡的，他那個是在夾那個檢體。醫師：欸那個滿快的餒，他那只打一個小洞進去夾檢體出來化驗而已。家屬：啊他現在是比較怕是肺結核。醫師：對，你是在擔心是肺結核。家屬：對啊，怕那個不好。醫師：那個我們是吃三個月的嗎？民眾：對啊。醫師：你心臟不好肚子也會脹喔，你上游喔，那個血液比較打不出去，因為你那個瓣膜狹窄，要擠血液出去時擠不太出去。民眾：對啦，現在就是比較怕那個瓣膜......。家屬：那個瓣膜功能好像剩五十二百分比。醫師：剩五十二百分比喔，那你那時候沒有考慮，陳醫師沒有建議你說......。家屬：啊他要開刀......你說開刀嗎？還是？他說那個要開刀換瓣膜要自費，他要兩百多萬。醫師：
# ...

# %%
import pandas as pd
import numpy as np
import json
import re
import pickle

# %%
datadir1 = {}
for i, j in datadir.items():
    f = []
    for k1, k2 in enumerate(j):
        if k1 == 0:
            c1 = k2
        else:
            f.append(k2)
    f1 = []
    for l in f:
        f1.append(l.split('\t'))
    y = np.array(f1)        
    df = pd.DataFrame(y[1:,:], columns=y[0,:])
    name = 'data' + str(i) + '.csv'
    df.to_csv('./data/' + name, index=False)
    datadir1[i] = (c1, name)

# %%
datadir1[3]
# Out:
# ('民眾：黃醫師我是想要請問你那個，阿之前腎盂炎住院的時候你有發現我有腎臟的水泡的問題，對，然後我印象中那時候你有跟我說就是水泡是小小的，如果不要造成有什麼不適，其實我們就定期追蹤這樣子……醫師：對對，ok。民眾：對，可是因為我後來就是在做其他健康檢查的時候，我有發現我好像又長一個。醫師：又長一個這樣？民眾：對。醫師：你是同側嗎？民眾：痾好像也是在右側。醫師：在右側是不是？民眾：對。醫師：你自己有感覺對不對？民眾：我自己覺得有一點不舒服……醫師：你覺得不舒服？民眾：然後所以我就會……痾會覺得那個不舒服應該推測是那個的關係，然後因為其實之後做檢查，醫生有說大概有9公分。醫師：5……5公分？民眾：9公分。醫師：好那我們看一下……所以以前好像沒有那麼大我印象中沒那麼大……阿你最近有要……感染嗎還是？民眾：痾是因為一直覺得有不適……醫師：不適？民眾：就是有不適感，不是常常，可是因為偶爾有，對，然後尤其是只要稍微覺得好像吃多一點或者是……醫師：吃多一點？民眾：對對對，就會覺得有腹脹的感覺，對，然後因為在想說之後還是有想要懷孕……醫師：懷孕嗎？民眾：因為又覺得十公分其實好像畢竟也不小，所以我想說想要聽聽看陳醫師的意見。醫師：倒是……假如你想要懷孕的話……因為懷孕的時候有時候會增加尿道感染的機會……民眾：喔。醫師：所以假如能夠處理掉的話……這是2……2016年10月19號的，因為你是右邊腎臟嗎，你可以看到這張超音波照片……你可以看到這是三年半前……民眾：恩。醫師：這邊看起來都還ok，這大小，這右邊的腎臟……民眾：恩。醫師：這右邊的腎臟，那這RK就是rightkidney，R是right。然後我們看一下今年的，這邊就多了一個這個，這之前沒有誒。民眾：對，因為我記得醫生你跟我說你……就是你有照到的那個是長在腎臟上的，然後是小小的。醫師：對，是這一個。民眾：對對對。醫師：是這個，這個，這個好像是多出來的……rightkidney……它好像跟……它好像跟腎臟沒有連接誒……rightkidney……rightkidney……對，你看它這邊腎臟右邊是還好誒，對，你看。民眾：恩。醫師：右邊的。民眾：這個範圍是腎臟？醫師：對，是範圍是腎臟，所以它……它好像是旁邊的，沒有從他那邊長出來。民眾：跟腎臟是沒有連接？醫師：是沒有關係誒，那我看一下你的電腦斷層。你在今年的年初有做過一次電腦斷層。民眾：
# ...

# %%
df = pd.read_csv('./data/data0.csv')
df
# Out:
#     article_id  start_position  end_position entity_text entity_type
# 0            0              55            57          68    med_exam
# 1            0              66            68          68    med_exam
# 2            0            1264          1271     10.78公分    med_exam
# 3            0            1358          1361         三多路    location
# 4            0            1374          1378        長庚醫院    location
# 5            0            1863          1865          十天        time
# 6            0            2072          2076        打撲克牌  profession
# 7            0            2575          2578         四五天        time
# 8            0            2604          2609       3月18號        time
# 9            0            2630          2635       3月24日        time
# 10           0            2650          2654        3月24        time
# 11           0            2663          2666         禮拜二        time
# 12           0            2667          2670         禮拜四        time
# ...

# %%
#存成json檔
json.dump(datadir1, open('./data/fordata.json', "w", encoding="utf-8"))

# %%
#仔入json檔
with open('./data/fordata.json', 'r', encoding="utf-8") as ff:
    datadir1 = json.load(ff)

# %%
#存成 pickle
with open('./data/data.pickle', 'wb') as f:
    pickle.dump(datadir1, f)

# %%
#載入 pickle
with open('./data/data.pickle', 'rb') as f:
    dicdata = pickle.load(f)

# %%
ss = datadir1['0'][0]

# %%
def forsplit(s):
    l1 = []
    l2 = []
    lis = s.split('：')
    for i in range(0, len(lis)):
        if i == 0:
            l1.append(lis[i])
        elif i == len(lis) - 1:
            l2.append(lis[i])
        else:
            l2.append(lis[i][0:-2])
            x = lis[i][-2:-1] + lis[i][-1]
            l1.append(x)
    return l1, l2

# %%
x, y = forsplit(datadir1['0'][0])

# %%
len(y)
# Out:
# 141

# %%
len(x)
# Out:
# 141

# %%
x
# Out:
# ['醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
#  '民眾',
#  '醫師',
# ...

# %%
y
# Out:
# ['你有做超音波嘛，那我們來看報告，有些部分有紅字耶。',
#  '紅字是甚麼意思？',
#  '就是肝功能有比較高，肝功能68，就是這個ALP是68，這樣比較高，正常應是50以下，另外就是你之前說你有B肝，但是你B肝已經好了耶。',
#  '它會自動修復阿。',
#  '你有抗體了阿，所以你B肝已經沒帶原了耶。',
#  '我以前被關的時候，就有在固定驗血，那時候說有B肝。',
#  '阿你現在已經有保護的抗體了。但是你現在有C肝。',
#  'C肝？',
#  'C型肝炎，A、B、C的C型肝炎。這部分你沒有檢查過對不對。',
#  '沒有耶，但是一般被關的時候都會驗血，還是他只會驗B肝沒有驗C肝？',
#  '一般都會這樣耶。',
#  '但是那時候他只跟我說B肝，沒C肝。',
#  '那你那是甚麼時候做的檢查？',
#  '很久以前了。',
#  '我建議這個C肝要檢查一下。',
#  '要怎麼檢查？要抽血嗎？',
#  '要再做進一步更精密的檢查，看C型肝炎的基因，這樣比較準。然後另外就是我建議你做是因為現在C肝目前有藥物可以治療。',
#  '恩對。',
#  '你知道嘛，C肝因為有符合歐洲的標準，政府會幫你出錢。',
#  '喔～',
#  '可以申請看看。',
#  '喔～',
#  '阿這個是意外發現啦。',
#  '喔～',
#  '對阿，所以我們就會另外看一下。也許已經好了，假如在測病毒的基因，假如測起來好了，那也沒關係，但你要確定，要再做進一步的檢查確定這樣子。',
#  '喔～',
#  '阿超音波的話，你說你都是腰側右側這邊會痛嗎？',
#  '恩，這邊會痛。他這個有可能是因為我坐骨神經痛，會不會是因為我久沒去復健，才會這樣？',
#  '一般都是如果有受傷過或是做工作的話，有受傷過的話，那個脊椎尾骨壓到神經。',
#  '喔～那會引起這樣狀況嗎？',
#  '他會繞一圈拉，他如果是神經的話。',
#  '對，他通常都從後面腰椎右側這邊開始痛起來。',
#  '這樣喔。',
#  '想說所以真的會這樣影響到嗎？',
#  '這邊是坐骨神經耶，上面這邊是脊椎耶。',
#  '不是，我本來受傷的時候我走路都會不太能走，然後去復健的時候都會拉開，拉開才比較會好。然後我現在手還會痛。',
#  '你腰椎痛跟手痛會有關係嗎？',
# ...

# %%
datadir1['0'][0]
# Out:
# '醫師：你有做超音波嘛，那我們來看報告，有些部分有紅字耶。民眾：紅字是甚麼意思？醫師：就是肝功能有比較高，肝功能68，就是這個ALP是68，這樣比較高，正常應是50以下，另外就是你之前說你有B肝，但是你B肝已經好了耶。民眾：它會自動修復阿。醫師：你有抗體了阿，所以你B肝已經沒帶原了耶。民眾：我以前被關的時候，就有在固定驗血，那時候說有B肝。醫師：阿你現在已經有保護的抗體了。但是你現在有C肝。民眾：C肝？醫師：C型肝炎，A、B、C的C型肝炎。這部分你沒有檢查過對不對。民眾：沒有耶，但是一般被關的時候都會驗血，還是他只會驗B肝沒有驗C肝？醫師：一般都會這樣耶。民眾：但是那時候他只跟我說B肝，沒C肝。醫師：那你那是甚麼時候做的檢查？民眾：很久以前了。醫師：我建議這個C肝要檢查一下。民眾：要怎麼檢查？要抽血嗎？醫師：要再做進一步更精密的檢查，看C型肝炎的基因，這樣比較準。然後另外就是我建議你做是因為現在C肝目前有藥物可以治療。民眾：恩對。醫師：你知道嘛，C肝因為有符合歐洲的標準，政府會幫你出錢。民眾：喔～醫師：可以申請看看。民眾：喔～醫師：阿這個是意外發現啦。民眾：喔～醫師：對阿，所以我們就會另外看一下。也許已經好了，假如在測病毒的基因，假如測起來好了，那也沒關係，但你要確定，要再做進一步的檢查確定這樣子。民眾：喔～醫師：阿超音波的話，你說你都是腰側右側這邊會痛嗎？民眾：恩，這邊會痛。他這個有可能是因為我坐骨神經痛，會不會是因為我久沒去復健，才會這樣？醫師：一般都是如果有受傷過或是做工作的話，有受傷過的話，那個脊椎尾骨壓到神經。民眾：喔～那會引起這樣狀況嗎？醫師：他會繞一圈拉，他如果是神經的話。民眾：對，他通常都從後面腰椎右側這邊開始痛起來。醫師：這樣喔。民眾：想說所以真的會這樣影響到嗎？醫師：這邊是坐骨神經耶，上面這邊是脊椎耶。民眾：不是，我本來受傷的時候我走路都會不太能走，然後去復健的時候都會拉開，拉開才比較會好。然後我現在手還會痛。醫師：你腰椎痛跟手痛會有關係嗎？民眾：不知道耶。醫師：因為你這邊是腰椎耶，受傷比較多，然後上面這個地方是胸椎耶。民眾：喔，算是不同這樣就對了喔。醫師：對，那所以胸椎這邊會痛嗎，你會嗎？民眾：不會耶。就是腰椎這邊會刺痛，有時候會，有時候不會，抽痛抽痛這樣。醫師：那看一下超音波影像左邊，這裡是肝臟，然後探頭是放肚子中間這邊。民眾：恩。醫師：
# ...

# %%
#總整理
import pandas as pd
import numpy as np
import json
import re
import pickle

def forsplit(s, arr):
    l1 = []            #一句話是由誰講的
    l2 = []            #講了什麼
    lis = s.split('：')
    arr0 = np.copy(arr[1:,:])   #註記矩陣
    for i in range(0, len(lis)):
        if i == 0:
            l1.append(lis[i] + '：')
        elif i == len(lis) - 1:
            l2.append(lis[i])
        else:
            l2.append(lis[i][0:-2])
            x = lis[i][-2:-1] + lis[i][-1]
            l1.append(x + '：')
    
    r = arr0.shape[0]        #共幾串文字需要註記
    w = len(l1[0])           #紀錄現在的字元總數
    s = 0                    #紀錄正要設定的註記位置
    for i in range(len(l2)):
        if s == r:
            break
        for j in range(s, r):
            if int(arr0[j, 1]) <= w + len(l2[i]):
                arr0[j, 0] = i
                #print('w=', w, '  int=', int(arr0[j, 1]))
                arr0[j, 1] = int(arr0[j, 1]) - w
                arr0[j, 2] = int(arr0[j, 2]) - w
                s += 1
            elif int(arr0[j, 1]) > w + len(l2[i]):
                try:
                    w += len(l2[i]) + len(l1[i+1])
                except:
                    print('八成是 i + 1 超過了')
                break
                
    return l1, l2, arr0

def dataprocess(path):
    datalist=[]
    with open(path, 'r', encoding="utf-8") as f:
        x = ''
        for line in f:
            if line != '--------------------\n':
                x = x + line + '\n'
            else:
                datalist.append(x)
                x = ''
    datadir = {}
    for i, j in enumerate(datalist):
        c = []
        c1 = j.split('\n')
        for k in c1:
            if k:
                c.append(k)
                datadir[i] = c
    
    datadir1 = {}
    for i, j in datadir.items():
        f = []
        for k1, k2 in enumerate(j):
            if k1 == 0:
                c1 = k2
            else:
                f.append(k2)
        f1 = []
        for l in f:
            f1.append(l.split('\t'))
        y = np.array(f1)        
        datadir1[i] = (c1, y)
    
    datadir2 = {}
    for i, j in datadir1.items():
        x1, x2, x3 = forsplit(j[0], j[1])
        datadir2[i] = (x1, x2, x3)
        
    return datadir2

# %%
dir = dataprocess('./competive_data/SampleData_deid.txt')

# %%
dir[0]
# Out:
# (['醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
#   '醫師：',
#   '民眾：',
# ...

# %%
with open('./data/data.pickle', 'wb') as f:
    pickle.dump(dir, f)

# %%
with open('./data/data.pickle', 'rb') as f:
    t = pickle.load(f)

# %%
for i, j in t.items():
    print(j[2])
# Out:
# [['2' '13' '15' '68' 'med_exam']
#  ['2' '24' '26' '68' 'med_exam']
#  ['56' '33' '40' '10.78公分' 'med_exam']
#  ['59' '14' '17' '三多路' 'location']
#  ['59' '30' '34' '長庚醫院' 'location']
#  ['79' '21' '23' '十天' 'time']
#  ['91' '1' '5' '打撲克牌' 'profession']
#  ['121' '5' '8' '四五天' 'time']
#  ['123' '9' '14' '3月18號' 'time']
#  ['125' '8' '13' '3月24日' 'time']
#  ['127' '0' '4' '3月24' 'time']
#  ['128' '0' '3' '禮拜二' 'time']
#  ['128' '4' '7' '禮拜四' 'time']
#  ['129' '2' '7' '3月31日' 'time']]
# [['30' '7' '11' '奇美醫院' 'location']
#  ['49' '6' '9' '三個月' 'time']
#  ['53' '9' '15' '五十二百分比' 'med_exam']
#  ['54' '1' '7' '五十二百分比' 'med_exam']
#  ['54' '19' '22' '陳醫師' 'name']
#  ['55' '36' '40' '兩百多萬' 'money']
#  ['56' '1' '5' '兩百多萬' 'money']
#  ['57' '15' '19' '兩百多萬' 'money']
#  ['59' '4' '7' '五個月' 'time']
#  ['75' '19' '24' '二零一六年' 'time']
#  ['75' '31' '33' '四年' 'time']
#  ['76' '3' '5' '四年' 'time']
#  ['77' '4' '6' '四年' 'time']
#  ['123' '0' '4' '一個半月' 'time']
#  ['125' '4' '8' '兩個禮拜' 'time']
# ...

# %%
#開啟教育部常用字檔
import xlwt

# %%
import sys

# %%
print(sys.getdefaultencoding())
# Out:
# utf-8

# %%
str = "this is string example....wow!!!"
strx = str.encode()

print(strx)
print("Decoded String: " + strx.decode())
# Out:
# b'this is string example....wow!!!'
# Decoded String: this is string example....wow!!!

# %%
str = "this is string example....wow!!!"
print(str.encode('utf-8','strict'))
# Out:
# b'this is string example....wow!!!'

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
ord('，')
# Out:
# 65292

# %%
# unicode string
string = 'aaaaaaa'

# print string
print('The string is:', string)

# default encoding to utf-8
string_utf = string.encode()

# print result
print('The encoded version is:', string_utf)
# Out:
# The string is: aaaaaaa
# The encoded version is: b'aaaaaaa'

# %%
s='再'
print(type(s)) #檢視s的字元型別
print(s)
s0 = s.encode()
print(s0) #解碼utf8，預設的編碼方式是unicode
print(s.encode('big5'))
s0.decode('utf-8')
# Out:
# <class 'str'>
# 再
# b'\xe5\x86\x8d'
# b'\xa6A'
# '再'

# %%
ord('再')
# Out:
# 20877

# %%
b'\xe5\x86\x8d'.decode('utf-8')
# Out:
# '再'

# %%
words = []
with open('常用字.txt', 'r', encoding='utf-8') as f:
    for i in f.readlines():
        words.append(i[-2])

# %%
len(words)
# Out:
# 4808

# %%
with open('./data/words.pickle', 'wb') as f:
    pickle.dump(words, f)

# %%
with open('./data/words.pickle', 'rb') as f:
    words2 = pickle.load(f)

# %%
words2
# Out:
# ['一',
#  '丁',
#  '七',
#  '三',
#  '下',
#  '丈',
#  '上',
#  '丑',
#  '丐',
#  '不',
#  '丙',
#  '世',
#  '丕',
#  '且',
#  '丘',
#  '丞',
#  '丟',
#  '並',
#  '丫',
#  '中',
#  '串',
#  '丸',
#  '凡',
#  '丹',
#  '主',
#  '乃',
#  '久',
#  '么',
#  '之',
#  '尹',
#  '乍',
#  '乏',
#  '乎',
#  '乒',
#  '乓',
#  '乖',
#  '乘',
#  '乙',
#  '九',
#  '也',
#  '乞',
#  '乩',
#  '乳',
#  '乾',
#  '亂',
#  '了',
#  '予',
#  '事',
#  '二',
#  '于',
#  '云',
#  '井',
#  '互',
#  '五',
#  '亙',
#  '些',
#  '亞',
#  '亟',
#  '亡',
#  '交',
#  '亦',
#  '亥',
#  '亨',
#  '享',
#  '京',
#  '亭',
#  '亮',
#  '人',
#  '仁',
#  '什',
#  '仃',
#  '仆',
#  '仇',
#  '仍',
#  '今',
#  '介',
#  '仄',
#  '以',
#  '付',
#  '仔',
#  '仕',
#  '他',
#  '仗',
#  '代',
#  '令',
#  '仙',
#  '仞',
#  '仿',
#  '伉',
#  '伙',
#  '伊',
#  '伕',
#  '伍',
#  '伐',
#  '休',
#  '伏',
#  '仲',
#  '件',
#  '任',
#  '仰',
#  '仳',
#  '份',
#  '企',
#  '位',
#  '住',
#  '佇',
#  '佗',
#  '佞',
#  '伴',
#  '佛',
#  '何',
#  '估',
#  '佐',
#  '佑',
#  '伽',
#  '伺',
#  '伸',
#  '佃',
#  '佔',
#  '似',
#  '但',
#  '佣',
#  '作',
#  '你',
#  '伯',
# ...
